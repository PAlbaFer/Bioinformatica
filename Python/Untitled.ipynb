# %% [markdown]
# # Mi primer Notebook

# %% [markdown]
# ## ... y esto es lo que voy a hacer:

# %% [markdown]
# ### Una lista *enumerada*:
# 1. Primero
# 2. Segundo
# 3. Tercero

# %% [markdown]
# ### Mi primer código:

# %%
mi_primera_frase = "Hello world"

# %%
#no ejecuta, necesario usar función print()
print(mi_primera_frase)
# Out:
# Hello world

# %%
#otra prueba:
numeros = (10,20,30,40,50)

# %%
media = sum(numeros)/len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# ### Finalizamos con una bonita imagen

# %% [markdown]
# ![img](img1.png)
